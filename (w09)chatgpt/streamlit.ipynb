# %%
# !pip install streamlit==1.28.2
# Out:
# Collecting streamlit==1.28.2
#   Downloading streamlit-1.28.2-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 13.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (0.8.1b0)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (4.11.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (0.10.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (8.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (9.2.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (5.1)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (5.3.1)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (13.6.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (6.1)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (2.28.1)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (8.0.4)
# Requirement already satisfied: protobuf<5,>=3.20 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (4.23.4)
# Requirement already satisfied: altair<6,>=4.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (5.0.1)
# Requirement already satisfied: pyarrow>=6.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (12.0.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (1.4.4)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (2.8.2)
# Requirement already satisfied: validators<1,>=0.2 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (0.22.0)
# Requirement already satisfied: packaging<24,>=16.8 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (21.3)
# Requirement already satisfied: numpy<2,>=1.19.3 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (1.26.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (4.7.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from streamlit==1.28.2) (1.6.2)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit==1.28.2) (4.16.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit==1.28.2) (2.11.3)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit==1.28.2) (0.11.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.28.2) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata<7,>=1.4->streamlit==1.28.2) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging<24,>=16.8->streamlit==1.28.2) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit==1.28.2) (2022.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.3->streamlit==1.28.2) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit==1.28.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit==1.28.2) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit==1.28.2) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit==1.28.2) (1.26.11)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit==1.28.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit==1.28.2) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.28.2) (5.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair<6,>=4.0->streamlit==1.28.2) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.28.2) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.28.2) (21.4.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.28.2) (0.1.2)
# Installing collected packages: streamlit
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.27.2
#     Uninstalling streamlit-1.27.2:
#       Successfully uninstalled streamlit-1.27.2
# Successfully installed streamlit-1.28.2

# %%
from openai import OpenAI
import streamlit as st

instructions = """
#봇 정보
 - 너는 내담자를 위로하고 정신과 치료를 도와주는 심리상담사야
 - 너는 내담자의 고민에 깊은 고민을 하고 대답해야해
 - 너는 내담자의 고민에 충분히 공감해주고 적절한 해결책을 제시해줘야해
 - 너의 대답은 반드시 50자 이하로 해야해
 - 내담자를 부르는 호칭은 반드시 "선생님"으로 해야해

#봇 응답 예시
Q: 갑자기 우울이 밀려올 때면 나 자신이 너무 가치 없게 느껴진다.
A: 세상에 가치없는 사람은 없어요 모두 다 가치있고 소중해요 선생님도 소중한 사람이에요 그 사실을 잊지말았으면 좋겠어요 
"""

st.title("고민 상담소")
client = OpenAI(api_key="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")

if "openai_model" not in st.session_state:
    st.session_state["openai_model"] = "gpt-3.5-turbo"

if "messages" not in st.session_state:
    st.session_state.messages = []

for message in st.session_state.messages:
    with st.chat_message(message["role"]):
        st.markdown(message["content"])

if prompt := st.chat_input("당신의 고민을 말씀해주세요"):
    st.session_state.messages.append({"role": "user", "content": prompt})
    with st.chat_message("user"):
        st.markdown(prompt)

    with st.chat_message("assistant"):
        message_placeholder = st.empty()
        full_response = ""

        messages = [
            {"role": m["role"], "content": m["content"]}
            for m in st.session_state.messages
        ]
        messages.insert(0, {"role": "system", "content": instructions})

        stream = client.chat.completions.create(
            model=st.session_state["openai_model"],
            messages=messages,
            stream=True,
        )
        for response in stream:  # pylint: disable=not-an-iterable
            full_response += response.choices[0].delta.content or ""
            message_placeholder.markdown(full_response + "▌")
        message_placeholder.markdown(full_response)
    st.session_state.messages.append({"role": "assistant", "content": full_response})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state.py:394, in SessionState.__getitem__(self, key)
#     393 try:
# --> 394     return self._getitem(widget_id, key)
#     395 except KeyError:
#
# File /opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state.py:439, in SessionState._getitem(self, widget_id, user_key)
#     438 # We'll never get here
# --> 439 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state_proxy.py:119, in SessionStateProxy.__getattr__(self, key)
#     118 try:
# --> 119     return self[key]
#     120 except KeyError:
#
# File /opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state_proxy.py:90, in SessionStateProxy.__getitem__(self, key)
#      89 require_valid_user_key(key)
# ---> 90 return get_session_state()[key]
#
# File /opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/safe_session_state.py:113, in SafeSessionState.__getitem__(self, key)
#     111     raise KeyError(key)
# --> 113 return self._state[key]
#
# File /opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state.py:396, in SessionState.__getitem__(self, key)
#     395 except KeyError:
# --> 396     raise KeyError(_missing_key_error_message(key))
#
# KeyError: 'st.session_state has no key "messages". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 26>()
#      23 if "messages" not in st.session_state:
#      24     st.session_state.messages = []
# ---> 26 for message in st.session_state.messages:
#      27     with st.chat_message(message["role"]):
#      28         st.markdown(message["content"])
#
# File /opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state_proxy.py:121, in SessionStateProxy.__getattr__(self, key)
#     119     return self[key]
#     120 except KeyError:
# --> 121     raise AttributeError(_missing_attr_error_message(key))
#
# AttributeError: st.session_state has no attribute "messages". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization
